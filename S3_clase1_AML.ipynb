# %% [markdown]
# # Clase 1 - Semana 3
# #### Tópicos Selectos Proceso Químicos: Análisis de Datos con Python

# %% [markdown]
# La función **input()** sirve para recibir datos del usuario durante la ejecución de un programa. Es una forma de interactuar con el usuario permitiéndole introducir texto, números u otra información que luego puede ser procesada por el código.

# %%
nombre = input("¿Cuál es tu nombre? ") # Recibir un nombre
print("Hola,", nombre) #Para mostrar infromación en la pantalla
# Out:
# ¿Cuál es tu nombre? Abi
# Hola, Abi

# %% [markdown]
# **Operadores** son símbolos especiales que permiten realizar operaciones con variables y valores.

# %% [markdown]
# Operadores aritméticos

# %% [markdown]
# | **Operación** | **Descripción** |
# |----------------|----------------|
# | `a + b` | Suma `a` y `b`. |
# | `a - b` | Resta `b` de `a`. |
# | `a * b` | Multiplica `a` por `b`. |
# | `a / b` | Divide `a` por `b`. |
# | `a // b` | División entera de `a` entre `b`. Calcula el cociente sin tener en cuenta el resto. |
# | `a % b` | Devuelve el módulo (residuo) de la división de `a` entre `b`. |
# | `a ** b` | Eleva `a` a la potencia de `b`. |
# | `-a` | Cambia el signo de `a` (negación aritmética). |
# | `+a` | Devuelve el valor positivo de `a`. |

# %% [markdown]
# Ejemplos:

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3 #División entera
# Out:
# 3

# %%
10 % 3 #Módulo (Residuo)
# Out:
# 1

# %%
2**3*(9+123)
# Out:
# 1056

# %% [markdown]
# Operadores relacionales o de comparación. Comparan valores y devuelven True o False

# %% [markdown]
# | **Operación** | **Descripción** |
# |----------------|----------------|
# | `a == b` | `True` si `a` es igual a `b`. |
# | `a != b` | `True` si `a` no es igual a `b`. |
# | `a < b`, `a <= b` | `True` si `a` es menor (o menor o igual) que `b`. |
# | `a > b`, `a >= b` | `True` si `a` es mayor (o mayor o igual) que `b`. |

# %% [markdown]
# **Ejemplos**

# %%
a = 7
b = 10

a > b
# Out:
# False

# %% [markdown]
# Operadores lógicos
#
# Se usan para combinar condiciones booleanas (True o False).

# %% [markdown]
# | **Operación** | **Descripción** |
# |----------------|----------------|
# | `a & b` | `True` si tanto `a` como `b` son `True`
# | `a and b` | `True` si tanto `a` como `b` son `True`. |
# | `a or b` | `True` si `a` o `b` son `True`. Si al menos una es True. |
# | `a ^ b` | Para booleanos, `True` si `a` o `b` son `True`, pero no ambos
# | `not a` | `True` si `a` es `False`. Negación lógica. |
# | `a in b` | `True` si `a` se encuentra dentro de `b` (por ejemplo, en una lista o cadena). |

# %% [markdown]
# Ejemplo **AND**

# %%
(5 > 3) and (2 < 4)
# Out:
# True

# %%
(5 > 3) & (2 < 4)
# Out:
# True

# %% [markdown]
# Ejemplo **OR**

# %%
(5 > 3) or (2 > 4)
# Out:
# True

# %% [markdown]
# Ejemplo **NOT**

# %%
not(5 > 3) #Invierte el valor lógico
# Out:
# False

# %% [markdown]
# ## **Paqueterías y Módulos**

# %% [markdown]
# Una paquetería (o paquete) en Python es un conjunto organizado de módulos, que contienen funciones, clases y variables listas para usar.

# %% [markdown]
# ![libreria.png](data:image/png;base64,...)

# %% [markdown]
# | Paquetería   | Uso principal                             |
# | ------------ | ----------------------------------------- |
# | `numpy`      | Operaciones con arreglos y matrices       |
# | `pandas`     | Análisis y manejo de datos                |
# | `matplotlib` | Gráficas y visualización                  |
# | `scipy`      | Cálculos científicos                      |
# | `sklearn`    | Aprendizaje automático (machine learning) |
# | `requests`   | Conexiones a internet y APIs              |

# %% [markdown]
# Un módulo es un archivo que contiene código Python (funciones, variables o clases) que puedes importar y reutilizar en otros programas.

# %% [markdown]
# Diferencia entre módulo y paquetería

# %% [markdown]
# | Concepto       | Qué es                                                                           | Ejemplo                 |
# | -------------- | -------------------------------------------------------------------------------- | ----------------------- |
# | **Módulo**     | Un solo archivo `.py` que contiene código reutilizable.                          | `math.py` |
# | **Paquetería** | Una **carpeta** que contiene varios módulos y un archivo especial | `numpy`, `pandas`       |

# %% [markdown]
# ## **Solución de ecuaciones**

# %% [markdown]
# Supongan que queremos resolver la ecuación cuadrática de la forma:
#
# $$
# ax^2 + bx+c=0,
# $$
#
# entonces, tenemos las soluciones:
#
# $$
# x_1 = \frac{-b-\sqrt{b^2-4ac}}{2a}
# $$
# y
#
# $$
# x_2 = \frac{-b+\sqrt{b^2-4ac}}{2a}
# $$
# para $a,b,c\in\mathbb{R}.$

# %% [markdown]
# Resolver
#
# $$
# 3x^2 + 2x-1 =0.
# $$
#
#  Almacenamos los valores de $a, b $ y $ c $.

# %%
a=-1
b=2
c=3

# %% [markdown]
#  **math** para operaciones matemática:
#
# -Operaciones básicas: sqrt(), pow(), ceil(), floor(), trunc(), fabs().
#
# -Trigonometricas: sin(), cos(), tan(), asin(), acos(), atan(), degrees(), radians().
#
# -Logarítmicas: log(), log10(), log2(), exp().
#
# -Constantes: pi, e.
#
# -Funciones especiales: gamma(), factorial().

# %%
import math

# %%
x1=((-b)+math.sqrt(b**2-4*a*c))/2*a
x2=((-b)-math.sqrt(b**2-4*a*c))/2*a

# %%
x1
# Out:
# -1.0

# %%
x2
# Out:
# 3.0

# %% [markdown]
# # Control de Flujo

# %% [markdown]
# Python tiene varias palabras clave internas para lógica condicional, bucles y otros conceptos estándares de control de flujo, que pueden encontrarse en otros lenguajes de programación.

# %% [markdown]
# ## if, elif y else
# permiten que el programa tome decisiones según condiciones

# %% [markdown]
# La sentencia **if** es uno de los tipos de sentencia de control de flujo más conocidos. Comprueba una condición, se ejecuta si la condición es verdadera.

# %%
x = -56

if x < 0:
    print('x es negativo')
# Out:
# x es negativo

# %% [markdown]
# if → se ejecuta si la condición es verdadera.
#
# elif → se ejecuta si la anterior fue falsa, pero esta verdadera.
#
# else → se ejecuta si ninguna condición anterior fue verdadera. No lleva condición

# %% [markdown]
# Una sentencia *if* puede ir seguida de manera opcional por uno o más bloques **elif** y un bloque multifuncional **else** si todas las condiciones son False:

# %%
x = 18

# %%
if x < 0:
  print('x es negativo') #sangría 4 espacios
elif x==0:
    print('x es igual a cero')
else:
    print('x es positivo ')
# Out:
# x es positivo

# %% [markdown]
# Ejemplo con input

# %%
n = int(input("Ingresa un número: "))

if n > 0:
    print("El número es positivo")
elif n < 0:
    print("El número es negativo")
else:
    print("El número es cero")
# Out:
# Ingresa un número: 5
# El número es positivo

# %% [markdown]
# Dada una ecuación cuadrática $$ax^2 + bx+c=0,$$
#
# El discriminante (Δ = b² - 4ac) determina el tipo de raíces:
#
# Δ > 0 → Dos raíces reales distintas
#
# Δ = 0 → Una raíz real doble
#
# Δ < 0 → Dos raíces complejas conjugadas
#
# Ejercicio: Escribe un código que:
# indique el tipo de raíces e emprima el valor si son reales.

# %%
a=1
b=4
c=5

# %%
D = b**2 - 4*a*c


if D > 0:
    x1 = (-b + math.sqrt(D)) / (2*a)
    x2 = (-b - math.sqrt(D)) / (2*a)
    print("Dos raíces reales distintas:", x1, x2)
elif D == 0:
    x = -b / (2*a)
    print("Una raíz real doble:", x)
else:
    print("Raíces complejas conjugadas")
# Out:
# Raíces complejas conjugadas

# %% [markdown]
# **Ejemplo Notas clase**
#
# - Menos de 6,es NA
# - De 6 a menos de 7.6, es S
# - De 7.6 a menos de 8.6,es B
# - De 8.6 a 10, es MB

# %%
# Calificación final

cal = float(input("Ingresa tu calificación (0-10):  "))

if cal >= 8.6 and cal <= 10:
    print("MB")
elif cal >= 7.6 and cal <= 8.5:
    print("B")
elif cal >=6 and cal <= 7.5:
    print("S")
else:
    print("NA")
# Out:
# Ingresa tu calificación (0-10):  5
# NA

# %% [markdown]
# **CONCLUSIÓN**
#   Las estructuras if, elif y else permiten que un programa reaccione a las condiciones del proceso, igual que un operador o un sistema de control lo haría en una planta química.
